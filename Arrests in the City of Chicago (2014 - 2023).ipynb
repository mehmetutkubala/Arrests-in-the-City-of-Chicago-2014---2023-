# %% [markdown]
# # Arrests in the City of Chicago (2014 - 2023)

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",100)

from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("chicago_arrests.csv") #https://www.kaggle.com/datasets/mattop/arrests-in-the-city-of-chicago-2014-2023

# %% [markdown]
# ### EDA

# %%
df
# Out:
#            CB_NO CASE NUMBER             ARREST DATE            RACE  \
# 0       18922700         NaN  06/26/2014 10:51:00 PM           BLACK
# 1       18922086         NaN  06/26/2014 12:07:00 AM           BLACK
# 2       18908465    HX290868  06/05/2014 11:58:00 AM           BLACK
# 3       18914257    HX302763  06/14/2014 04:50:00 AM           BLACK
# 4       18911035         NaN  06/09/2014 08:45:00 AM           BLACK
# ...          ...         ...                     ...             ...
# 585413  30209325    JG117312  01/15/2023 04:02:00 PM           BLACK
# 585414  30209368    JG117594  01/15/2023 07:41:00 PM           BLACK
# 585415  30209388    JG117599  01/15/2023 09:27:00 PM  WHITE HISPANIC
# 585416  30209311         NaN  01/15/2023 03:16:00 PM  WHITE HISPANIC
# 585417  30209346         NaN  01/15/2023 05:55:00 PM  WHITE HISPANIC
#
#                CHARGE 1 STATUTE  \
# 0            725 ILCS 5.0/110-3
# 1          625 ILCS 5.0/6-303-A
# 2          720 ILCS 570.0/402-C
# 3         720 ILCS 5.0/12-3-A-1
# 4                       8-4-030
# ...                         ...
# 585413  720 ILCS 5.0/24-1.6-A-1
# 585414     720 ILCS 570.0/402-C
# 585415       720 ILCS 550.0/4-D
# 585416     625 ILCS 5.0/6-303-A
# 585417     625 ILCS 5.0/6-303-A
#
#                                      CHARGE 1 DESCRIPTION CHARGE 1 TYPE  \
# 0                                     ISSUANCE OF WARRANT           NaN
# 1                            DRIVING ON SUSPENDED LICENSE             M
# 2       PCS - POSSESSION - POSS AMT CON SUB EXCEPT (A)(D)             F
# 3                             BATTERY - CAUSE BODILY HARM             M
# 4                      DRINKING ALCOHOL ON THE PUBLIC WAY           NaN
# ...                                                   ...           ...
# 585413                     AGG UUW/VEHICLE/LOADED/NO FCCA             F
# 585414  PCS - POSSESSION - POSS AMT CON SUB EXCEPT (A)(D)             F
# 585415                         POSS CAN/>100-500 GRAM/1ST             F
# 585416                       DRIVING ON SUSPENDED LICENSE             M
# 585417                       DRIVING ON SUSPENDED LICENSE             M
#
#        CHARGE 1 CLASS         CHARGE 2 STATUTE  \
# 0                   Z                      NaN
# 1                   A              9-76-160(A)
# 2                   4     720 ILCS 600.0/3.5-A
# 3                   A        520 ILCS 5.0/1.22
# 4                   L                      NaN
# ...               ...                      ...
# 585413              4                      NaN
# 585414              4  625 ILCS 5.0/11-501-A-4
# 585415              4     625 ILCS 5.0/3-701-1
# 585416              A              9-76-160(F)
# 585417              A              9-12-050(B)
#
#                          CHARGE 2 DESCRIPTION CHARGE 2 TYPE CHARGE 2 CLASS  \
# 0                                         NaN           NaN            NaN
# 1                   DISPLAY ST REG-FRONT/REAR           NaN              L
# 2          PCS - DRUG PARAPHERNALIA - POSSESS             M              A
# 3                     RESIST/OBSTRUCT OFFICER             M              A
# 4                                         NaN           NaN            NaN
# ...                                       ...           ...            ...
# 585413                                    NaN           NaN            NaN
# 585414  IVC - DRIVING UNDER INFLUENCE OF DRUG             M              A
# 585415                  NO VALID REGISTRATION           NaN              P
# 585416                    REGISTRATION PLATES           NaN              L
# 585417                 LANES, FAIL TO KEEP IN           NaN              L
#
#                 CHARGE 3 STATUTE         CHARGE 3 DESCRIPTION CHARGE 3 TYPE  \
# 0                            NaN                          NaN           NaN
# 1                            NaN                          NaN           NaN
# 2                            NaN                          NaN           NaN
# 3          720 ILCS 5.0/12-3-A-1  BATTERY - CAUSE BODILY HARM             M
# 4                            NaN                          NaN           NaN
# ...                          ...                          ...           ...
# 585413                       NaN                          NaN           NaN
# 585414  625 ILCS 5.0/11-502.15-B  UNLWFL POSS CANNABIS/DRIVER             M
# 585415                       NaN                          NaN           NaN
# 585416                       NaN                          NaN           NaN
# 585417                       NaN                          NaN           NaN
#
#        CHARGE 3 CLASS      CHARGE 4 STATUTE          CHARGE 4 DESCRIPTION  \
# 0                 NaN                   NaN                           NaN
# 1                 NaN                   NaN                           NaN
# 2                 NaN                   NaN                           NaN
# 3                   A                   NaN                           NaN
# 4                 NaN                   NaN                           NaN
# ...               ...                   ...                           ...
# 585413            NaN                   NaN                           NaN
# 585414              A  625 ILCS 5.0/3-702-B  USE CANC/REVOKE REGISTRATION
# 585415            NaN                   NaN                           NaN
# 585416            NaN                   NaN                           NaN
# 585417            NaN                   NaN                           NaN
#
#        CHARGE 4 TYPE CHARGE 4 CLASS  \
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 585413           NaN            NaN
# 585414             M              A
# 585415           NaN            NaN
# 585416           NaN            NaN
# 585417           NaN            NaN
#
#                                           CHARGES STATUTE  \
# 0                              725 ILCS 5.0/110-3 |  |  |
# 1                 625 ILCS 5.0/6-303-A | 9-76-160(A) |  |
# 2        720 ILCS 570.0/402-C | 720 ILCS 600.0/3.5-A |  |
# 3       720 ILCS 5.0/12-3-A-1 | 520 ILCS 5.0/1.22 | 72...
# 4                                         8-4-030 |  |  |
# ...                                                   ...
# 585413                    720 ILCS 5.0/24-1.6-A-1 |  |  |
# 585414  720 ILCS 570.0/402-C | 625 ILCS 5.0/11-501-A-4...
# 585415     720 ILCS 550.0/4-D | 625 ILCS 5.0/3-701-1 |  |
# 585416            625 ILCS 5.0/6-303-A | 9-76-160(F) |  |
# 585417            625 ILCS 5.0/6-303-A | 9-12-050(B) |  |
#
#                                       CHARGES DESCRIPTION   CHARGES TYPE  \
# 0                             ISSUANCE OF WARRANT |  |  |        |  |  |
# 1       DRIVING ON SUSPENDED LICENSE | DISPLAY ST REG-...      M |  |  |
# 2       PCS - POSSESSION - POSS AMT CON SUB EXCEPT (A)...     F | M |  |
# 3       BATTERY - CAUSE BODILY HARM | RESIST/OBSTRUCT ...    M | M | M |
# 4              DRINKING ALCOHOL ON THE PUBLIC WAY |  |  |        |  |  |
# ...                                                   ...            ...
# 585413             AGG UUW/VEHICLE/LOADED/NO FCCA |  |  |      F |  |  |
# 585414  PCS - POSSESSION - POSS AMT CON SUB EXCEPT (A)...  F | M | M | M
# 585415  POSS CAN/>100-500 GRAM/1ST | NO VALID REGISTRA...      F |  |  |
# 585416  DRIVING ON SUSPENDED LICENSE | REGISTRATION PL...      M |  |  |
# 585417  DRIVING ON SUSPENDED LICENSE | LANES, FAIL TO ...      M |  |  |
#
#         CHARGES CLASS
# 0           Z |  |  |
# 1          A | L |  |
# 2          4 | A |  |
# 3         A | A | A |
# 4           L |  |  |
# ...               ...
# 585413      4 |  |  |
# 585414  4 | A | A | A
# 585415     4 | P |  |
# 585416     A | L |  |
# 585417     A | L |  |
#
# [585418 rows x 24 columns]

# %%
df.isnull().sum() #We examine the empty lines.
# Out:
# CB_NO                        0
# CASE NUMBER             227460
# ARREST DATE                  0
# RACE                         0
# CHARGE 1 STATUTE             0
# CHARGE 1 DESCRIPTION         0
# CHARGE 1 TYPE           126509
# CHARGE 1 CLASS            4716
# CHARGE 2 STATUTE        337455
# CHARGE 2 DESCRIPTION    337455
# CHARGE 2 TYPE           444510
# CHARGE 2 CLASS          339657
# CHARGE 3 STATUTE        449367
# CHARGE 3 DESCRIPTION    449367
# CHARGE 3 TYPE           538332
# CHARGE 3 CLASS          450006
# CHARGE 4 STATUTE        510008
# CHARGE 4 DESCRIPTION    510008
# CHARGE 4 TYPE           566328
# CHARGE 4 CLASS          510211
# CHARGES STATUTE              0
# CHARGES DESCRIPTION          0
# CHARGES TYPE                 0
# CHARGES CLASS                0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
df["CHARGES STATUTE"].value_counts()
# Out:
# 725 ILCS 5.0/110-3 |  |  |                                                                          69175
# 720 ILCS 570.0/402-C |  |  |                                                                        22075
# 720 ILCS 5.0/16-25-A-1 |  |  |                                                                      20503
# 720 ILCS 5.0/12-3.2-A-1 |  |  |                                                                     17854
# 720 ILCS 5.0/12-3.2-A-2 |  |  |                                                                     15162
#                                                                                                     ...
# 720 ILCS 5.0/16-1-A-1 | 720 ILCS 5.0/21-1-A-1 | 720 ILCS 5.0/32-10-A |                                  1
# 625 ILCS 5.0/11-501-A-2 | 625 ILCS 5.0/3-707 | 9-16-020(C) | 625 ILCS 5.0/6-101                         1
# 720 ILCS 5.0/24-1.1-A | 720 ILCS 550.0/4-B | 9-40-220 | 625 ILCS 5.0/6-101                              1
# 720 ILCS 5.0/16-25-A-4 | 1-4-145-A |  |                                                                 1
# 720 ILCS 570.0/402-C | 625 ILCS 5.0/11-501-A-4 | 625 ILCS 5.0/11-502.15-B | 625 ILCS 5.0/3-702-B        1
# Name: CHARGES STATUTE, Length: 85221, dtype: int64

# %%
df=df.drop(["CHARGES STATUTE","CHARGES DESCRIPTION","CHARGES TYPE","CHARGES CLASS","CASE NUMBER"],axis=1)
#We delete some columns.

# %%
df["CHARGE 2 STATUTE"].fillna("None",inplace=True)
df["CHARGE 2 DESCRIPTION"].fillna("None",inplace=True)
df["CHARGE 2 TYPE"].fillna("None",inplace=True)
df["CHARGE 2 CLASS"].fillna("None",inplace=True)
df["CHARGE 3 STATUTE"].fillna("None",inplace=True)
df["CHARGE 3 DESCRIPTION"].fillna("None",inplace=True)
df["CHARGE 3 TYPE"].fillna("None",inplace=True)
df["CHARGE 3 CLASS"].fillna("None",inplace=True)
df["CHARGE 4 STATUTE"].fillna("None",inplace=True)
df["CHARGE 4 DESCRIPTION"].fillna("None",inplace=True)
df["CHARGE 4 TYPE"].fillna("None",inplace=True)
df["CHARGE 4 CLASS"].fillna("None",inplace=True)
#We change empty data to None.

# %%
df=df.dropna() #We delete rows containing empty data.

# %%
df["ARREST DATE"]=pd.to_datetime(df["ARREST DATE"])
df["day"]=(df["ARREST DATE"]).dt.day
df["month"]=(df["ARREST DATE"]).dt.month
df["year"]=(df["ARREST DATE"]).dt.year
df["time"]=(df["ARREST DATE"]).dt.time
del df["ARREST DATE"]
#We divide ARREST DATE into 4 as day, month, year and hour.

# %%
df["RACE"].value_counts()
# Out:
# BLACK                           327000
# WHITE HISPANIC                   84054
# WHITE                            40413
# BLACK HISPANIC                    3193
# ASIAN / PACIFIC ISLANDER          3048
# UNKNOWN / REFUSED                  757
# AMER INDIAN / ALASKAN NATIVE       280
# Name: RACE, dtype: int64

# %%
df=df[df['RACE']!="UNKNOWN / REFUSED"] #We delete UNKNOWN / REFUSED data in RACE.
df["RACE"]=df["RACE"].map({"BLACK":0,"BLACK HISPANIC":0,"WHITE HISPANIC":1,"WHITE":1,"ASIAN / PACIFIC ISLANDER":2,"AMER INDIAN / ALASKAN NATIVE":2})
#We change the data in RACE to 0,1 and 2.
df['RACE']=df['RACE'].astype(int) #We change the type of data in Race to integer.

# %%
df=df[df['year']>2021] #We delete the data in year that is less than 2022.

# %%
abs(df.corr()['RACE']).sort_values(ascending=False)
# Out:
# RACE     1.000000
# month    0.010804
# CB_NO    0.009366
# year     0.001662
# day      0.000666
# Name: RACE, dtype: float64

# %% [markdown]
# ### Classification

# %%
x,y=df.drop(["CB_NO","RACE","year","day"],axis=1),df[["RACE"]]
x=pd.get_dummies(x,drop_first=True)
smote = SMOTE(sampling_strategy='minority')
x_sm, y_sm = smote.fit_resample(x, y)
x_sm=scaler.fit_transform(x_sm)
x.shape
# Out:
# (30421, 6092)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
model=Sequential()
model.add(Dense(16,activation="relu"))
model.add(Dense(32,activation="relu"))
model.add(Dense(64,activation="relu"))
model.add(Dense(8,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss="binary_crossentropy",optimizer="adam",metrics="accuracy")

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=10,epochs=50,verbose=1)
model.summary()
# Out:
# Epoch 1/50
# 2434/2434 [==============================] - 5s 2ms/step - loss: 0.5876 - accuracy: 0.7095 - val_loss: 0.5657 - val_accuracy: 0.7256
# Epoch 2/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: 0.5491 - accuracy: 0.7260 - val_loss: 0.5720 - val_accuracy: 0.7256
# Epoch 3/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: 0.5183 - accuracy: 0.7420 - val_loss: 0.5814 - val_accuracy: 0.7224
# Epoch 4/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: 0.4868 - accuracy: 0.7525 - val_loss: 0.6398 - val_accuracy: 0.6975
# Epoch 5/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: 0.4420 - accuracy: 0.7670 - val_loss: 0.7637 - val_accuracy: 0.6838
# Epoch 6/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: 0.3403 - accuracy: 0.7747 - val_loss: 1.0029 - val_accuracy: 0.6920
# Epoch 7/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -0.2306 - accuracy: 0.7779 - val_loss: 7.8334 - val_accuracy: 0.6789
# Epoch 8/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -2.5338 - accuracy: 0.7759 - val_loss: 3.2287 - val_accuracy: 0.7139
# Epoch 9/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -10.6041 - accuracy: 0.7752 - val_loss: 13.8598 - val_accuracy: 0.6924
# Epoch 10/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -30.0649 - accuracy: 0.7641 - val_loss: 54.3977 - val_accuracy: 0.6896
# Epoch 11/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -75.4318 - accuracy: 0.7557 - val_loss: 128.8264 - val_accuracy: 0.6782
# Epoch 12/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -161.1092 - accuracy: 0.7494 - val_loss: 74.8802 - val_accuracy: 0.6797
# Epoch 13/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -331.5686 - accuracy: 0.7592 - val_loss: 264.8138 - val_accuracy: 0.6868
# Epoch 14/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -619.0393 - accuracy: 0.7480 - val_loss: 481.6984 - val_accuracy: 0.7029
# Epoch 15/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1087.3900 - accuracy: 0.7447 - val_loss: 763.3405 - val_accuracy: 0.6932
# Epoch 16/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1751.3131 - accuracy: 0.7431 - val_loss: 2833.3818 - val_accuracy: 0.6375
# Epoch 17/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -2807.5686 - accuracy: 0.7446 - val_loss: 1384.4386 - val_accuracy: 0.7037
# Epoch 18/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -4198.5181 - accuracy: 0.7458 - val_loss: 5713.1636 - val_accuracy: 0.6933
# Epoch 19/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -6114.8687 - accuracy: 0.7506 - val_loss: 4668.0405 - val_accuracy: 0.7085
# Epoch 20/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -8650.0068 - accuracy: 0.7478 - val_loss: 6632.2900 - val_accuracy: 0.6636
# Epoch 21/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -12222.6123 - accuracy: 0.7509 - val_loss: 11130.3809 - val_accuracy: 0.6963
# Epoch 22/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -16654.9316 - accuracy: 0.7527 - val_loss: 13940.8662 - val_accuracy: 0.4845
# Epoch 23/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -22958.0020 - accuracy: 0.7555 - val_loss: 26614.2793 - val_accuracy: 0.6804
# Epoch 24/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -29796.5703 - accuracy: 0.7546 - val_loss: 38065.2812 - val_accuracy: 0.7030
# Epoch 25/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -38168.0938 - accuracy: 0.7590 - val_loss: 41877.2031 - val_accuracy: 0.6878
# Epoch 26/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -49285.4805 - accuracy: 0.7612 - val_loss: 51996.1289 - val_accuracy: 0.6979
# Epoch 27/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -63427.6172 - accuracy: 0.7641 - val_loss: 63397.4531 - val_accuracy: 0.6753
# Epoch 28/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -78966.5156 - accuracy: 0.7580 - val_loss: 121989.5391 - val_accuracy: 0.6953
# Epoch 29/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -98340.0000 - accuracy: 0.7601 - val_loss: 57869.8945 - val_accuracy: 0.6955
# Epoch 30/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -120277.7422 - accuracy: 0.7610 - val_loss: 123060.7891 - val_accuracy: 0.6544
# Epoch 31/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -147883.1250 - accuracy: 0.6780 - val_loss: 122834.6875 - val_accuracy: 0.7108
# Epoch 32/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -179495.0000 - accuracy: 0.7191 - val_loss: 164066.0625 - val_accuracy: 0.7104
# Epoch 33/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -216808.5156 - accuracy: 0.7192 - val_loss: 208857.1406 - val_accuracy: 0.7098
# Epoch 34/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -261191.6094 - accuracy: 0.7186 - val_loss: 171310.3750 - val_accuracy: 0.7114
# Epoch 35/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -308744.1562 - accuracy: 0.7183 - val_loss: 260078.7656 - val_accuracy: 0.7103
# Epoch 36/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -366610.3750 - accuracy: 0.7188 - val_loss: 299386.5000 - val_accuracy: 0.7094
# Epoch 37/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -429740.9375 - accuracy: 0.7181 - val_loss: 458302.3125 - val_accuracy: 0.7108
# Epoch 38/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -504913.5938 - accuracy: 0.7170 - val_loss: 509215.3750 - val_accuracy: 0.7111
# Epoch 39/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -582253.6875 - accuracy: 0.7177 - val_loss: 430432.7188 - val_accuracy: 0.7118
# Epoch 40/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -677959.7500 - accuracy: 0.7173 - val_loss: 717238.5625 - val_accuracy: 0.7104
# Epoch 41/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -785066.4375 - accuracy: 0.7175 - val_loss: 581713.1250 - val_accuracy: 0.7113
# Epoch 42/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -900849.8750 - accuracy: 0.7179 - val_loss: 948113.1875 - val_accuracy: 0.7121
# Epoch 43/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1037803.5625 - accuracy: 0.7180 - val_loss: 838413.0625 - val_accuracy: 0.7114
# Epoch 44/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1176536.3750 - accuracy: 0.7177 - val_loss: 864350.6875 - val_accuracy: 0.7111
# Epoch 45/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1350179.1250 - accuracy: 0.7187 - val_loss: 1167948.6250 - val_accuracy: 0.7124
# Epoch 46/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1521791.2500 - accuracy: 0.7179 - val_loss: 1680023.8750 - val_accuracy: 0.7113
# Epoch 47/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1728911.8750 - accuracy: 0.7182 - val_loss: 1290538.7500 - val_accuracy: 0.7104
# Epoch 48/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -1935374.2500 - accuracy: 0.7175 - val_loss: 1508024.7500 - val_accuracy: 0.7108
# Epoch 49/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -2186057.5000 - accuracy: 0.7178 - val_loss: 1687008.7500 - val_accuracy: 0.7094
# Epoch 50/50
# 2434/2434 [==============================] - 4s 2ms/step - loss: -2458857.0000 - accuracy: 0.7179 - val_loss: 2416665.5000 - val_accuracy: 0.7114
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 16)                97488
#
#  dense_6 (Dense)             (None, 32)                544
#
#  dense_7 (Dense)             (None, 64)                2112
#  dense_8 (Dense)             (None, 8)                 520
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 100,673
# Trainable params: 100,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores=model.evaluate(x_test,y_test)
# Out:
# 191/191 [==============================] - 0s 1ms/step - loss: 2416666.0000 - accuracy: 0.7114
